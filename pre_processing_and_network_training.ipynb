# %% [markdown]
# ### Introducción a procesamiento inteligente de imágenes con Star Wars

# %% [markdown]
# #### $whoami
#
# #TODO data e imagenes de linuxchix y ayudantes del tuto http://www.linuxchixar.org/

# %% [markdown]
# ### Bibliotecas a utilizar
#
# #TODO breve intro pandas, cv2, numpy, lasagne, flask o quizas algo desktop con pygame?
# #TODO instalación

# %% [markdown]
# #### Cargando Imágenes a un Dataframe

# %%
import os
import pandas as pd
import cv2

# %%
def images_to_file(path_to_photos):
    ids = [os.path.splitext(image_id)[0] for image_id in os.listdir(path_to_photos)]
    df_out = pd.DataFrame(columns=['Image', 'Model', 'Model_enc'], index=ids)
    for image_file in os.listdir(path_to_photos):
            image = cv2.imread(os.path.join(path_to_photos, image_file), 0)
            df_out['Image'][os.path.splitext(image_file)[0]] = ' '.join(map(str, image.flatten()))
            df_out['Model'][os.path.splitext(image_file)[0]] = image_file.split('_')[0]
       
    catenc = pd.factorize(df_out['Model'])
    df_out['Model_enc'] = catenc[0]
    df_out.to_csv('/tmp/star_wars_data.csv')
    return df_out

# %%
images_to_file("data/all/")
# Out:
#                                                         Image   Model  \
# falcon_060  255 255 255 255 255 255 255 255 255 255 255 25...  falcon
# falcon_071  255 255 255 255 255 255 255 255 255 255 255 25...  falcon
# falcon_074  255 255 255 255 255 255 255 255 255 255 255 25...  falcon
# falcon_059  255 255 255 255 255 255 255 255 255 255 255 25...  falcon
# falcon_063  255 255 255 255 255 255 255 255 255 255 255 25...  falcon
# kwing_1     170 171 173 173 171 172 172 170 168 169 169 16...   kwing
# falcon_29   51 54 62 52 57 53 51 104 133 139 104 38 44 57 ...  falcon
# lambda_04   160 162 164 163 162 159 155 151 149 148 147 14...  lambda
# kwing_5     145 145 145 147 148 148 149 150 145 145 146 14...   kwing
# falcon_25   123 142 147 150 160 166 171 177 181 186 188 19...  falcon
# lambda_01   133 137 137 135 136 141 145 144 142 143 143 14...  lambda
# kwing_058   255 255 255 255 255 255 255 255 255 255 255 25...   kwing
# falcon_073  255 255 255 255 255 255 255 255 255 255 255 25...  falcon
# falcon_12   147 150 154 150 140 141 151 157 164 147 118 15...  falcon
# kwing_45    74 77 80 80 79 81 82 83 82 83 84 81 83 88 129 ...   kwing
# falcon_33   188 188 189 191 192 193 193 193 193 191 191 19...  falcon
# falcon_14   75 64 53 58 56 55 62 61 67 59 57 52 49 46 40 4...  falcon
# lambda_15   255 255 255 255 255 255 255 255 255 255 255 25...  lambda
# falcon_076  255 255 255 255 255 255 255 255 255 255 255 25...  falcon
# kwing_49    5 44 139 149 147 147 147 110 24 13 50 79 103 1...   kwing
# falcon_077  255 255 255 255 255 255 255 255 255 255 255 25...  falcon
# lambda_03   60 56 57 55 53 53 51 48 55 119 167 173 173 175...  lambda
# kwing_52    74 73 77 76 76 75 89 130 145 146 154 158 159 1...   kwing
# falcon_02   189 188 188 188 189 189 189 189 188 188 188 18...  falcon
# lambda_19   255 255 255 255 255 255 255 255 255 255 255 25...  lambda
# falcon_18   98 100 100 87 77 79 83 83 80 72 65 65 66 66 69...  falcon
# kwing_8     147 150 161 171 174 180 187 189 190 186 185 18...   kwing
# kwing_51    75 75 79 76 78 75 107 141 147 152 156 159 154 ...   kwing
# falcon_04   207 207 207 208 210 212 214 215 216 213 212 21...  falcon
# lambda_09   255 255 255 255 255 255 255 255 255 255 255 25...  lambda
# ...                                                       ...     ...
# falcon_064  255 255 255 255 255 255 255 255 255 255 255 25...  falcon
255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 2
# 55 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 2
# 55 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 2
# 55 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 2
# 55 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 2
# 55 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 252 254 255 2
# 35 210 201 203 219 240 254 255 253 253 255 255 255 255 255 255 255 255 255 255 2
# 55 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 2
# 55 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 2
# 55 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 2
# 55 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 2
# 55 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 2

# %%
import numpy as np
from sklearn.utils import shuffle

# %%
def load(images_dir="data/all/"):
    """Loads data"""
    df = images_to_file(images_dir)
    df['Image'] = df['Image'].apply(lambda im: np.fromstring(im, sep=' '))

    df = df.dropna()
    X = np.vstack(df['Image'].values) / 255.  # scale pixel values to [0, 1]

    # pca_white = decomposition.RandomizedPCA() #(whiten=True)
    # X = pca_white.fit_transform(X)
    # print pca_white.explained_variance_ratio_
    X = X.astype(np.float32)

    y = df['Model_enc'].values
    X, y = shuffle(X, y, random_state=42)  # shuffle train data
    y = y.astype(np.int32)
    
    return X, y

# %%
import theano
import lasagne
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.cross_validation import train_test_split
from lasagne.updates import nesterov_momentum
from nolearn.lasagne import NeuralNet
from nolearn.lasagne import BatchIterator
from lasagne.layers import InputLayer, Conv2DLayer, DropoutLayer,\
                           MaxPool2DLayer, DenseLayer
from nolearn.lasagne import visualize
# Out:
# Using gpu device 0: GeForce GTX 860M (CNMeM is disabled, CuDNN not available)
# /usr/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
class FlipBatchIterator(BatchIterator):

    def transform(self, xb, yb):
        xb, yb = super(FlipBatchIterator, self).transform(xb, yb)
        #  TODO remove this
        #angle = choice([-35, -45, 35, 45])
        #theta = angle * np.pi / 180.
        #rot_matrix = np.array([[np.cos(theta), -np.sin(theta)],
        #                      [np.sin(theta), np.cos(theta)]])

        # TODO this should be removed, was for rotate images
        bs = xb.shape[0]
        indices = np.random.choice(bs, bs / 2, replace=False)  # /2 choose all
        xb[indices] = xb[indices, :, :, ::-1]

        return xb, yb

# %%
class AdjustVariable(object):
    def __init__(self, name, start=0.03, stop=0.001):
        self.name = name
        self.start, self.stop = start, stop
        self.ls = None

    def __call__(self, nn, train_history):
        if self.ls is None:
            self.ls = np.linspace(self.start, self.stop, nn.max_epochs)

        epoch = train_history[-1]['epoch']
        new_value = np.float32(self.ls[epoch - 1])
        getattr(nn, self.name).set_value(new_value)

# %%
def create_net(max_epochs=100):
    return NeuralNet(
        layers=[
                (InputLayer, {'shape': (None, 1, 128, 128)}),
                (Conv2DLayer, {'num_filters': 64, 'filter_size': 3}),
                (MaxPool2DLayer, {'pool_size': 2}),
                (Conv2DLayer, {'num_filters': 32, 'filter_size': 2}),
                (MaxPool2DLayer, {'pool_size': 2}),
                (DenseLayer, {'num_units': 256, 'nonlinearity': lasagne.nonlinearities.rectify}),
                (DropoutLayer, {'p': 0.5}),
                (DenseLayer, {'num_units': 3, 'nonlinearity': lasagne.nonlinearities.softmax}),
        ],
        update=nesterov_momentum,
        update_learning_rate=theano.shared(np.float32(0.01)),
        update_momentum=theano.shared(np.float32(0.9)),
        regression=False,
        batch_iterator_train=FlipBatchIterator(batch_size=20),
        on_epoch_finished=[
            AdjustVariable('update_learning_rate', start=0.01, stop=0.001),
            AdjustVariable('update_momentum', start=0.9, stop=0.9999)  # ,
        ],
        max_epochs=max_epochs,
        verbose=1)

# %%
x, y = load()
x = x.reshape(-1, 1, 128, 128)
X_train, X_test, y_train, y_test = train_test_split(x, y,
                                                    test_size=0.25,
                                                    random_state=42)

# %%
net = create_net(70)
net.fit(X_train, y_train)
# Out:
# /usr/lib/python2.7/site-packages/lasagne/layers/conv.py:499: UserWarning: The `image_shape` keyword argument to `tensor.nnet.conv2d` is deprecated, it has been renamed to `input_shape`.
#   border_mode=border_mode)
# /usr/lib/python2.7/site-packages/nolearn/lasagne/base.py:416: UserWarning: The Param class is deprecated. Replace Param(default=N) by theano.In(value=N)
#   for input_layer in input_layers]
# /usr/lib/python2.7/site-packages/nolearn/lasagne/base.py:417: UserWarning: The Param class is deprecated. Replace Param(default=N) by theano.In(value=N)
#   inputs = X_inputs + [theano.Param(y_batch, name="y")]
# # Neural Network with 7882403 learnable parameters
#
# ## Layer information
#
#   #  name        size
# ---  ----------  ----------
#   0  input0      1x128x128
#   1  conv2d1     64x126x126
#   2  maxpool2d2  64x63x63
#   3  conv2d3     32x62x62
#   4  maxpool2d4  32x31x31
#   5  dense5      256
#   6  dropout6    256
#   7  dense7      3
#
#   epoch    train loss    valid loss    train/val    valid acc  dur
# -------  ------------  ------------  -----------  -----------
#      46       0.03614       0.29492      0.12253      0.88235  0.85s
#      47       0.01802       0.32638      0.05523      0.94118  0.85s
#      48       0.01003       0.39728      0.02524      0.88235  0.85s
#      49       0.03336       0.36018      0.09263      0.88235  0.85s
#      50       0.01403       0.30444      0.04609      0.94118  0.86s
#      51       0.00719       0.31001      0.02318      0.88235  0.85s
#      52       0.00928       0.30379      0.03054      0.88235  0.85s
#      53       0.02600       0.36409      0.07141      0.82353  0.85s
#      54       0.02093       0.30909      0.06772      0.88235  0.85s
#      55       0.00869       0.35273      0.02465      0.88235  0.86s
#      56       0.00393       0.51329      0.00766      0.88235  0.85s
#      57       0.00425       0.63117      0.00673      0.82353  0.85s
#      58       0.01547       0.36655      0.04221      0.88235  0.86s
#      59       0.00908       0.49326      0.01840      0.88235  0.85s
#      60       0.05638       0.30998      0.18187      0.88235  0.86s
#      61       0.02122       0.38275      0.05545      0.88235  0.85s
#      62       0.02295       0.43658      0.05256      0.82353  0.85s
#      63       0.04825       0.47403      0.10179      0.76471  0.86s
#      64       0.03799       0.48469      0.07838      0.76471  0.86s
#      65       0.03459       0.49220      0.07028      0.76471  0.85s
#      66       0.04119       0.49524      0.08316      0.76471  0.85s
#      67       0.02364       0.49415      0.04784      0.76471  0.85s
#      68       0.02346       0.49221      0.04766      0.76471  0.85s
#      69       0.02667       0.49072      0.05434      0.82353  0.85s
#      70       0.02206       0.48914      0.04511      0.82353  0.85s
# NeuralNet(X_tensor_type=None,
#      batch_iterator_test=<nolearn.lasagne.base.BatchIterator object at 0x7fb1bc284550>,
#      batch_iterator_train=<__main__.FlipBatchIterator object at 0x7fb1c63d4a10>,
#      custom_score=None,
#      layers=[(<class 'lasagne.layers.input.InputLayer'>, {'shape': (None, 1, 128, 128)}), (<class 'lasagne.layers.conv.Conv2DLayer'>, {'filter_size': 3, 'num_filters': 64}), (<class 'lasagne.layers.pool.MaxPool2DLayer'>, {'pool_size': 2}), (<class 'lasagne.layers.conv.Conv2DLayer'>, {'filter_size': 2, 'n....layers.dense.DenseLayer'>, {'num_units': 3, 'nonlinearity': <function softmax at 0x7fb1bd20b320>})],
#      loss=None, max_epochs=70, more_params={},
#      objective=<function objective at 0x7fb1bc287d70>,
#      objective_loss_function=<function categorical_crossentropy at 0x7fb1bcdbe578>,
#      on_epoch_finished=[<__main__.AdjustVariable object at 0x7fb1b4542190>, <__main__.AdjustVariable object at 0x7fb1b4542050>, <nolearn.lasagne.handlers.PrintLog instance at 0x7fb1b459d200>],
#      on_training_finished=[],
#      on_training_started=[<nolearn.lasagne.handlers.PrintLayerInfo instance at 0x7fb1b4533878>],
#      regression=False,
#      train_split=<nolearn.lasagne.base.TrainSplit object at 0x7fb1bc284590>,
#      update=<function nesterov_momentum at 0x7fb1bcdbee60>,
#      update_learning_rate=<TensorType(float32, scalar)>,
#      update_momentum=<TensorType(float32, scalar)>,
#      use_label_encoder=False, verbose=1,
#      y_tensor_type=TensorType(int32, vector))

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
# %matplotlib inline
visualize.plot_loss(net)

# %%
def plot_matrix(clf, X_test, y_test):
    """Plot Confussion Matrix from a given classifier"""
   
    plt.clf()
    
    cm = confusion_matrix(y_test, clf.predict(X_test))
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print('Normalized confusion matrix')
    cm_normalized[np.isnan(cm_normalized)] = 0.0
    print(cm_normalized)
    plt.tick_params(labelsize=20)
    ax = plt.imshow(cm_normalized, interpolation='nearest', cmap=plt.cm.Reds)
    cb = plt.colorbar()
    cb.ax.tick_params(axis='both', labelsize=20)
    plt.ylabel("True label", fontsize=20)
    plt.xlabel("Predicted label", fontsize=20)

# %%
plot_matrix(net, X_test, y_test)
# Out:
# Normalized confusion matrix
# [[ 0.94117647  0.          0.05882353]
#  [ 0.          1.          0.        ]
#  [ 0.5         0.375       0.125     ]]
