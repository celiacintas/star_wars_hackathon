# %% [markdown]
# # Introducción Matplotlib

# %%
from IPython.display import Image
Image(filename='images/convincing.png')

# %%
from IPython.display import IFrame
IFrame('http://matplotlib.org/', width=900, height=350)
# Out:
#         <iframe
#             width="900"
#             height="350"
#             src="http://matplotlib.org/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

# %%
print plt.style.available
plt.style.use(plt.style.available[0])
# Out:
# [u'seaborn-darkgrid', u'seaborn-notebook', u'classic', u'seaborn-ticks', u'grayscale', u'bmh', u'seaborn-talk', u'dark_background', u'ggplot', u'fivethirtyeight', u'seaborn-colorblind', u'seaborn-deep', u'seaborn-whitegrid', u'seaborn-bright', u'seaborn-poster', u'seaborn-muted', u'seaborn-paper', u'seaborn-white', u'seaborn-pastel', u'seaborn-dark', u'seaborn-dark-palette']

# %%
x = np.linspace(0, 2, 10)
x
# Out:
# array([ 0.        ,  0.22222222,  0.44444444,  0.66666667,  0.88888889,
#         1.11111111,  1.33333333,  1.55555556,  1.77777778,  2.        ])

# %%
plt.plot(x, x, 'o--', label='linear')
plt.plot(x, x ** 2, 'x-', label='quadratic')
plt.legend(loc='best')
plt.title('Linear vs Quadratic progression')
plt.xlabel('Input')
plt.ylabel('Output')
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.scatter(np.random.rand(100,), np.random.rand(100,))
# Out:
# <img src="data:image/png;base64,...">

# %%
my_conf_matrix = np.array([[337, 10, 4], [ 4, 401, 1], [ 2, 2, 369]]) 
plt.tick_params(labelsize=20)

ax = plt.imshow(my_conf_matrix, interpolation='nearest', cmap=plt.cm.Reds)
cb = plt.colorbar()
cb.ax.tick_params(axis='both', labelsize=20)
plt.ylabel("True label", fontsize=20)
plt.xlabel("Predicted label", fontsize=20)
plt.xticks(range(3),range(3))
plt.yticks(range(3),range(3))
# Out:
# <img src="data:image/png;base64,...">
# ([<matplotlib.axis.YTick at 0x7fc60c3b61d0>,
#   <matplotlib.axis.YTick at 0x7fc60c3b6d50>,
#   <matplotlib.axis.YTick at 0x7fc60c2fe6d0>],
#  <a list of 3 Text yticklabel objects>)
