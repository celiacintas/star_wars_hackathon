# %% [markdown]
# # Introducción a deep learning con python: El despertar de la fuerza

# %% [markdown]
# ### $whoami
#
# #TODO data e imagenes de linuxchix y ayudantes del tuto http://www.linuxchixar.org/

# %%
from IPython.display import Image
Image(filename='images/linux_star.png', width=600)

# %% [markdown]
# ### ¿Por qué empezaron LinuxChix Argentina?
#
# LinuxChix Argentina empezó con dos objetivos:
#
#    - Visibilizar a las mujeres en el mundo de GNU/Linux y del software libre
#    - Lograr que más mujeres se acerquen a ese mundo
#
# Como corolario, la idea fue crear una comunidad **más abierta y diversa** en la cual las personas puedan discutir sobre Linux; una comunidad que motive la participación e ideas de sus miembros sin importar su nivel de conocimiento
#
# ### ¿Es LinuxChix Argentina sólo para mujeres?
#
# **No**, LinuxChix es un grupo **inclusivo**. La idea es que toda la gente se sienta bienvenida. Pedimos, sin embargo, que tengan en mente que es un grupo que intenta ayudar a que más mujeres participen de las comunidades de software libre. Esto significa que cualquier comentario sexista es considerado inadecuado de y para cualquiera de sus miembros.
#
# ### Si los hombres son también bienvenidos, ¿por qué lo llamaron LinuxChix?
#
# LinuxChix busca específicamente visibilizar y naturalizar el hecho de que las mujeres también usamos y creamos software libre. El nombre es una reflejo del objetivo primordial del grupo.
#
# ### Todavía no sé usar Linux, ¿puedo unirme igual?
#
# ¡Si! Nos vamos a encargar de ayudarte a cambiar eso :)

# %%
from IPython.display import IFrame
IFrame('https://linuxchixar.github.io/linuxchixar-web/', width=900, height=350)
# Out:
#         <iframe
#             width="900"
#             height="350"
#             src="https://linuxchixar.github.io/linuxchixar-web/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# En este taller veremos una gentil introducción al mundo de deep learning (específicamente ConvNets) desde Python con la ayuda de librerías como [Lasagne](http://lasagne.readthedocs.io/en/latest/), [NumPy](http://www.numpy.org/), [Pandas](http://pandas.pydata.org/) y [OpenCV](http://opencv.org/) de la mano de nuestras naves favoritas de la franquicia Star Wars. En este tutorial caminaremos por el pipeline comenzando desde la adquisición de los datos, su preparación, construcción de ConvNets, su entrenamiento y evaluación, con el fin ulterior de poder clasificar distintos tipos de naves de Star Wars!!!
#
# Para este taller contaremos con miniaturas de las naves en la sala para que los participantes las utilicen como prueba y fuente de datos de sus clasificadores! En el tutorial mostraremos cómo clasificar las naves k-wing, lambda shuttle y millennium falcon. Pero también llevaremos un x-wing, TIE fighter y TIE phantom para que los participantes construyan sus propios clasificadores.

# %%
from IPython.display import Image
Image(filename='images/ships.png', width=700)

# %%
from IPython.display import Image
Image(filename='images/dependencies.png', width=700)

# %% [markdown]
# - [Instalación](Instalacion-00.ipynb)
# - [Rápida Introducción NumPy](Introduccion-NumPy-00.ipynb)
# - [Rápida Introducción a Pandas](Introduccion-Pandas-00.ipynb)
# - [Rápida Introducción a Matplotlib](Introduccion-Matplotlib-00.ipynb)
# - [Rápida Introducción a OpenCV](Introduccion-OpenCV-00.ipynb)
# - [Rápida Introducción a Deep Learning y Lasagne](Introduccion a Deep Learning y Lasagne.ipynb)
